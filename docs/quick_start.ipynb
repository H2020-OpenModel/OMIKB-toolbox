# %% [markdown]
# # First Steps

# %% [markdown]
# # Open an Account
# - the platform is open to all project partners in the first instance
# - there is a development and a stable (deployment) platform with addresses
#   - https://openmodel.app --> stable, may be down every friday for upgrade and maintenance from 10-14)
#   - https://dev_openmodel.app --> development, may not be always online
# - Visit https://openmodel.app
#   - **normally you would fill a form and a user is created manually**
#   - For todays session, we enable self registration, which will be disabled after the meeting.
#   - once registered log in.

# %% [markdown]
# # Clonning repositories
# - As example, we clone and install OMIKB
# - head to https://github.com/H2020-OpenModel and find the repository
# - Optional: create an ssh public key and add it to you github account, or use HTTPS but then you need a (Personal Access Token (PTA))[https://mgimond.github.io/Colby-summer-git-workshop-2021/authenticating-with-github.html]

# %% [markdown]
# `git clone https://github.com/H2020-OpenModel/OMIKB-toolbox.gi`
#
# switch to the relevant branch, in this case:
#
# `git fetah --all`
# `git checkout fix-ontoflow`

# %% [markdown]
# # Quick tour of JupyterHub and working with files

# %% [markdown]
# # Quick Tour or OMIKB

# %% [markdown]
# # If you do not see the OpenModel Exec Flow App
#
# this means your account is older than the new Docker Notebook Image. The system does not override your setup, so the easiest way is to install directly.
#
# ![image.png](attachment:3c35f7b4-9d10-4685-b58d-2e6bf1d9d765.png)
